# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import pickle

# %%
df = pd.read_csv("student_palcement.csv")

# %%
df
# Out:
#       student_id  age  gender      branch  cgpa  internship_count  \
# 0              1   23    Male          IT  8.99                 4
# 1              2   24  Female  Mechanical  8.36                 4
# 2              3   22  Female         EEE  7.18                 4
# 3              4   24  Female  Mechanical  6.28                 0
# 4              5   24  Female          IT  5.30                 3
# ...          ...  ...     ...         ...   ...               ...
# 9995        9996   21  Female         CSE  5.27                 4
# 9996        9997   21    Male  Mechanical  7.23                 0
# 9997        9998   21  Female       Civil  8.70                 1
# 9998        9999   21    Male  Mechanical  9.04                 3
# 9999       10000   23    Male         CSE  9.91                 2
#
#       project_count  certifications_count  coding_skills_score  \
# 0                 6                     2                   41
# 1                 7                     5                   42
# 2                 5                     2                   84
# 3                 2                     4                   60
# 4                 4                     1                   78
# ...             ...                   ...                  ...
# 9995              6                     0                   74
# 9996              7                     4                   58
# 9997              4                     2                   82
# 9998              5                     3                   86
# 9999              3                     4                   73
#
#       communication_skills_score  soft_skills_score hackathon_participation  \
# 0                             71                 59                     Yes
# 1                             64                 97                      No
# 2                             98                 51                      No
# 3                            100                 92                      No
# 4                             61                 77                      No
# ...                          ...                ...                     ...
# 9995                          65                 63                     Yes
# 9996                          95                 89                      No
# 9997                          42                 76                      No
# 9998                          72                 55                      No
# 9999                          78                 68                      No
#
#      placement_status
# 0              Placed
# 1              Placed
# 2              Placed
# 3          Not Placed
# 4          Not Placed
# ...               ...
# 9995       Not Placed
# 9996           Placed
# 9997       Not Placed
# 9998           Placed
# 9999           Placed
#
# [10000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# student_id                    0
# age                           0
# gender                        0
# branch                        0
# cgpa                          0
# internship_count              0
# project_count                 0
# certifications_count          0
# coding_skills_score           0
# communication_skills_score    0
# soft_skills_score             0
# hackathon_participation       0
# placement_status              0
# dtype: int64

# %%
df = df.drop(["student_id","hackathon_participation"], axis=1)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'branch', 'cgpa', 'internship_count', 'project_count',
#        'certifications_count', 'coding_skills_score',
#        'communication_skills_score', 'soft_skills_score', 'placement_status'],
#       dtype='object')

# %%
y = df["placement_status"]
x = df.drop("placement_status", axis=1)

# %%
x_train , x_test, y_train, y_test = train_test_split(
    x,y, test_size=0.2, stratify=y, random_state=42
)

# %%
cat_cols = x.select_dtypes(include="object").columns
num_cols = x.select_dtypes(exclude="object").columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
        ("num", "passthrough", num_cols)
    ]
)

# %%
pipeline = Pipeline([
    ("preprocessing", preprocessor),
    ("model", DecisionTreeClassifier(
        max_depth = 10,
        min_samples_leaf = 5,
        min_samples_split = 2,
        random_state=42
    ))
])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['gender', 'branch'], dtype='object')),
#                                                  ('num', 'passthrough',
#                                                   Index(['age', 'cgpa', 'internship_count', 'project_count',
#        'certifications_count', 'coding_skills_score',
#        'communication_skills_score', 'soft_skills_score'],
#       dtype='object'))])),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=10, min_samples_leaf=5,
#                                         random_state=42))])

# %%
y_pred = pipeline.predict(x_test)

# %%
print("classification report ", classification_report(y_test, y_pred))
# Out:
# classification report                precision    recall  f1-score   support
#
#   Not Placed       0.84      0.85      0.85       985
#       Placed       0.85      0.85      0.85      1015
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
with open("stp.pkl", "wb")as f:
    pickle.dump(pipeline,f)

print("model save successfully")
# Out:
# model save successfully

# %%
df["branch"].unique()
# Out:
# array(['IT', 'Mechanical', 'EEE', 'CSE', 'ECE', 'Civil'], dtype=object)
